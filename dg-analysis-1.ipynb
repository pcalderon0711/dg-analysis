# %%
import gensim
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from neurotools.io.gdrive import download_sheets_doc
from neurotools.io.files import load_embedding_model
from itertools import product
# %matplotlib inline

# %% [markdown]
# # PROCESS EMBEDDING AND DIMENSIONS

# %% [markdown]
# ## LOAD EMBEDDING AND DIMENSIONS

# %%
emb, word2rank_dict = load_embedding_model('005_en_in_commoncrawl_v1_20180330.bin')

# %%
cutoff = round((1/5)*len(word2rank_dict))

# %%
def get_average_vector(words, emb):
    """
        Average the word vectors of a list of words.
    """
    words_in_emb = [emb[word] for word in words if word in emb.vocab.keys()]
    total = np.sum(words_in_emb, axis=0)
    count = len(words_in_emb)
    return total / count

# %%
dimensions_doc_id = '1qa6hmUwjipTocTLIAIBEuObkzVGwWUvYXV04HjMw0BM'
dimensions_doc = download_sheets_doc(dimensions_doc_id, has_column_labels=True)
dimensions_nf = dimensions_doc['dimensions_v2.csv']
dimensions_nf = dimensions_nf.loc[(dimensions_nf['whisky_relevant'] == '1') & (dimensions_nf['en'] != ''), ['en_label', 'en']]
dimensions_nf['en_label'] = 'nf_' + dimensions_nf['en_label']

# %%
dimensions_nf
# Out:
#                 en_label                                                 en
# 7           nf_appealing  loved love positive desireable desire want asp...
# 59          nf_expensive                  Costly Extravagant Pricey Upscale
# 64        nf_fascination  fascination fascinated inspired intrigued capt...
# 69              nf_fresh  fresh activate, awaken/wake, rebirth, refresh,...
# 75   nf_healthy_positive  high-antioxidant vitamin rich healthy energy-b...
# 82             nf_winner  winner champ first award medal champion pride ...
# 100              nf_mild  mild safe, (skin) friendly, natural, harmony, ...
# 104            nf_modern  Contemporary, Current, Present-day, Latest, Fr...
# 114           nf_natural  natural balanced beneficial biodegradable biod...
# 118               nf_new                  new fresh all_new brand_new model
# 125          nf_pleasant  caress freedom health love peace cheer friend ...
# 148        nf_attractive  aesthetic appealing artful attractive awe-insp...
# 149             nf_Tasty  delectable delicious delightful dreamy enjoyab...
# 170            nf_trendy  trendy, trendy, stylish, fashionable, up-to-da...
# 189          nf_valuable  valuable, good_reputation, prestigious, recogn...
# 191              nf_warm  cheerful imaginative optimistic informal brave...

# %%
diageo_dimensions_doc_id = '1_OdlI2ieNMAXAepeqtjDIghRVj6Lgoaf9caiZK8jmkA'
diageo_dimensions_doc = download_sheets_doc(diageo_dimensions_doc_id, has_column_labels=True)
dimensions_diageo = diageo_dimensions_doc['Dimensions']
dimensions_diageo = dimensions_diageo.loc[dimensions_diageo['Content'] != '', ['Dimension', 'Content']]
dimensions_diageo['Dimension'] = 'dg_' + dimensions_diageo['Dimension']

# %%
dimensions_nf.columns = ['Dimension', 'Content']

# %%
dimensions_nf.shape
# Out:
# (16, 2)

# %%
dimensions = pd.concat([dimensions_diageo, dimensions_nf], axis=0, ignore_index=True)

# %%
dimensions.append{}

# %%
dimensions
# Out:
#                     Dimension  \
# 0                  dg_Relaxed
# 1                dg_Confident
# 2                dg_Welcoming
# 3                   dg_Social
# 4                  dg_Playful
# 5             dg_Street-Smart
# 6              dg_Progressive
# 7                  dg_Stylish
# 8                dg_Inspiring
# 9                dg_Authentic
# 10                dg_Friendly
# 11                    dg_Bold
# 12               dg_Inclusive
# 13                     dg_Fun
# 14              dg_Passionate
# 15                 dg_Refined
# 16                 dg_pungent
# 17                   dg_bland
# 18                  dg_bitter
# 19              dg_caramellic
# 20                    dg_malt
# 21                     dg_raw
# 22                  dg_smooth
# 23                   dg_spicy
# 24                   dg_sweet
# 25                   dg_smoky
# 26    dg_fullness, complexity
# 27                   dg_grain
# 28                 dg_matured
# 29  dg_vanilla, confectionery
# 30               nf_appealing
# 31               nf_expensive
# 32             nf_fascination
# 33                   nf_fresh
# 34        nf_healthy_positive
# 35                  nf_winner
# 36                    nf_mild
# 37                  nf_modern
# 38                 nf_natural
# 39                     nf_new
# 40                nf_pleasant
# 41              nf_attractive
# 42                   nf_Tasty
# 43                  nf_trendy
# 44                nf_valuable
# 45                    nf_warm
#
#                                               Content
# 0   relax unwind enjoy soothe calm serene leisurel...
# 1   confident optimistic hopeful reassure certainl...
# 2   welcome greet warmly hospitable invite graciou...
# 3           social civil collective community cordial
# 4   playful delightful lighthearted lively flirtat...
# 5   hardened astute cunning experienced savvy stre...
# 6              progressive dynamic enlightened modern
# 7   stylish classy chic trendy elegant fashionable...
# 8   inspired inspiration passionate incredible upl...
# 9              authentic genuine unique unpretentious
# 10  friendly courteous polite attentive nice enthu...
# 11  bold forceful adventurous courageous daring fe...
# 12  inclusive broad comprehensive involve represen...
# 13    fun playful frolic enjoy amuse excite adventure
# 14  passionate enthusiastic intensely energetic ha...
# 15  refine sophisticate distilled elegant aestheti...
# 16                  pungent acid acrid aromatic sharp
# 17              bland boring dull insipid tame watery
# 18             bitter harsh sour acid astringent tart
# 19                                caramellic, caramel
# 20                                               malt
# 21        raw basic coarse crude natural rough native
# 22  smooth creamy easy fluid gentle mild serene si...
# 23                   spicy aromatic fiery hot piquant
# 24                   sweet syrupy honeyed candy sugar
# 25                     smoky bruning dingy smoldering
# 26    fulness saturation totality wholeness ampleness
# 27                                         grain corn
# 28              matured cultivated cultured aged ripe
# 29                              vanilla confectionery
# 30  loved love positive desireable desire want asp...
# 31                  Costly Extravagant Pricey Upscale
# 32  fascination fascinated inspired intrigued capt...
# 33  fresh activate, awaken/wake, rebirth, refresh,...
# 34  high-antioxidant vitamin rich healthy energy-b...
# 35  winner champ first award medal champion pride ...
# 36  mild safe, (skin) friendly, natural, harmony, ...
# 37  Contemporary, Current, Present-day, Latest, Fr...
# 38  natural balanced beneficial biodegradable biod...
# 39                  new fresh all_new brand_new model
# 40  caress freedom health love peace cheer friend ...
# 41  aesthetic appealing artful attractive awe-insp...
# 42  delectable delicious delightful dreamy enjoyab...
# 43  trendy, trendy, stylish, fashionable, up-to-da...
# 44  valuable, good_reputation, prestigious, recogn...
# 45  cheerful imaginative optimistic informal brave...

# %%
emb['street']
# Out:
# array([ 9.06485438e-01, -1.98477373e-01,  8.48460972e-01,  5.06138563e+00,
#        -3.58491254e+00, -5.24342251e+00,  5.03968716e+00,  2.46836782e+00,
#        -1.57667208e+00,  3.99307537e+00,  1.76606810e+00,  3.51971316e+00,
#        -4.82044071e-01, -2.96393442e+00,  2.98825812e+00,  6.34178686e+00,
#         3.41874695e+00, -6.80340719e+00,  4.09660864e+00,  5.15216875e+00,
#         3.51979280e+00, -4.18580437e+00,  3.18653941e+00, -3.74957824e+00,
#         1.15288007e+00, -2.67013967e-01,  1.72129333e+00,  5.33731580e-01,
#         2.77903152e+00, -1.31512821e+00, -2.85506964e+00,  3.73316312e+00,
#         4.30917382e-01,  6.46688700e-01, -2.00630832e+00, -4.01146173e+00,
#         5.12015915e+00, -1.14160228e+00, -1.69475943e-01,  1.98474956e+00,
#         1.78286088e+00,  3.90369368e+00,  5.79096746e+00, -2.19927490e-01,
#         2.61757046e-01,  5.17830372e+00, -2.64075136e+00,  2.06870794e+00,
#         5.47280967e-01, -3.30385590e+00, -8.56038928e-01, -4.75514501e-01,
#         3.94387341e+00,  1.09143674e-01, -6.03426039e-01, -1.34973133e+00,
#         3.27428842e+00, -2.80229259e+00, -4.77626145e-01,  1.29283297e+00,
#         5.55354834e+00,  9.01332438e-01, -1.55877161e+00, -4.53463268e+00,
#         2.13963652e+00, -1.07546020e+00,  6.53696299e+00, -7.99600720e-01,
#        -6.17332602e+00,  1.94697988e+00, -4.28815508e+00,  1.03155005e+00,
#         1.76698923e+00, -1.85405731e+00,  1.33702862e+00,  2.86152649e+00,
#         6.32328510e-01,  2.24009705e+00,  8.51441383e-01, -1.73647368e+00,
#        -2.50159001e+00, -2.40758276e+00,  9.04408246e-02,  2.84956002e+00,
#        -3.88290834e+00,  5.62183475e+00, -5.67891884e+00, -8.16111946e+00,
#         1.02777444e-01, -1.96949649e+00,  2.29127741e+00, -3.84789252e+00,
#         3.12923640e-01,  1.67492604e+00,  2.72113538e+00,  6.27761111e-02,
#         1.34323847e+00,  1.35528827e+00,  1.57018101e+00, -2.95322490e+00,
#        -3.71643901e+00, -1.36859441e+00, -2.15426636e+00,  2.20382905e+00,
#        -1.72538137e+00,  1.24814725e+00, -3.62931299e+00, -9.13453460e-01,
#         6.15609109e-01,  5.64997244e+00, -2.54918051e+00,  2.34480977e+00,
#        -5.52158165e+00,  2.27394342e+00, -5.51752985e-01, -8.01074922e-01,
#        -2.69635129e+00, -1.55174625e+00,  3.97891212e+00,  2.21870112e+00,
#         2.93047285e+00,  2.80307555e+00,  1.28822565e+00, -5.97411096e-01,
#         3.40552855e+00, -2.75879860e+00,  3.24524212e+00,  2.89134141e-02,
#        -1.37108445e+00,  1.83447206e+00,  1.88399255e+00, -2.57713556e+00,
#         6.64776325e-01, -2.74742746e+00,  2.79593182e+00,  8.51339531e+00,
#        -2.53119135e+00,  3.90246820e+00, -1.23728967e+00, -4.88556242e+00,
#        -4.69037628e+00, -1.87360287e+00,  5.68926156e-01,  2.63934469e+00,
#         6.67104626e+00,  4.16634142e-01,  1.57211030e+00, -3.32504368e+00,
#        -4.10897464e-01,  6.83572245e+00,  2.14557672e+00,  1.80315113e+00,
#         6.51508999e+00, -5.50631857e+00, -2.61806273e+00,  2.37750912e+00,
#        -1.84964263e+00,  7.75109947e-01,  2.04061699e+00,  3.43146300e+00,
#        -3.59472394e-01, -3.47933221e+00, -2.38779330e+00,  5.85458612e+00,
#        -1.18084848e+00, -4.33431005e+00,  1.42189467e+00,  5.20147848e+00,
#         1.39553809e+00, -9.28618371e-01, -1.47272241e+00, -1.01113157e+01,
#         2.57333088e+00, -3.43426919e+00,  2.24229550e+00,  6.85715675e-01,
#         1.02978969e+00, -6.41599989e+00,  1.37022400e+00,  3.93453431e+00,
#        -3.27325583e+00, -3.07413697e+00,  2.75602770e+00, -2.89031458e+00,
#         2.65484715e+00,  6.02423096e+00, -1.18483245e+00,  5.69854546e+00,
#         4.74288225e+00, -8.23963702e-01,  5.39400876e-01,  1.81501698e+00,
#        -4.21602905e-01, -2.03336406e+00,  5.80815196e-01,  7.31043768e+00,
#         3.05096602e+00,  3.32907653e+00, -2.19158471e-01,  7.52897549e+00,
#         3.10646963e+00, -3.36058879e+00,  3.59736776e+00, -1.66398573e+00,
#        -8.22522402e-01,  2.90328145e+00,  1.59353152e-01, -4.56288958e+00,
#         4.84640980e+00,  1.22581780e+00,  4.02553558e+00,  1.12130678e+00,
#         3.79142094e+00, -2.64037251e-01, -7.77512848e-01, -4.43426228e+00,
#         6.94359541e-01,  1.05557179e+00, -1.35258961e+00, -9.94197071e-01,
#        -6.61420882e-01,  3.14674401e+00,  2.38704419e+00, -3.13145971e+00,
#         2.60883260e+00, -2.76005149e+00,  2.62776423e+00, -2.36886001e+00,
#        -2.15144777e+00, -4.98627520e+00,  5.44017196e-01, -4.16678190e+00,
#         1.11070894e-01,  1.46445060e+00, -4.88169193e+00,  5.01160765e+00,
#         1.31169462e+00, -1.69968247e+00, -4.84377289e+00, -1.94947016e+00,
#        -5.89303255e+00,  5.45546234e-01,  3.67633224e+00,  4.41760492e+00,
#         1.48198295e+00, -3.22410655e+00, -2.24886680e+00,  5.37501991e-01,
#        -3.16579372e-01, -2.68361831e+00, -1.73043656e+00, -7.49064088e-02,
#        -1.10824358e+00,  1.86581218e+00, -4.23909807e+00,  6.26774132e-01,
#        -2.58218956e+00, -1.42846465e+00,  2.67448163e+00, -5.34153998e-01,
#        -2.43502438e-01, -1.45663536e+00,  2.25663662e-01, -1.74816275e+00,
#         8.87220919e-01, -2.79830146e+00,  6.89728081e-01, -7.80067682e-01,
#        -6.47324705e+00, -5.38199472e+00, -2.36818269e-01, -1.03294710e-03,
#         8.55997086e+00,  1.75901818e+00, -2.97663897e-01,  2.73983932e+00,
#        -2.34582472e+00, -2.05425477e+00, -2.07771301e+00, -3.55399489e+00,
#         2.27506280e+00,  8.92721832e-01,  2.91820228e-01,  2.54320455e+00,
#         1.56481183e+00, -2.63394475e+00,  4.68991846e-01, -5.99527538e-01,
#        -2.06074262e+00,  2.82175207e+00,  7.68843770e-01,  6.86129987e-01,
#         4.85894251e+00, -2.00659490e+00, -2.03069305e+00, -3.04517627e-01,
#        -5.91052961e+00, -3.22384024e+00, -4.10294342e+00, -4.01116991e+00],
#       dtype=float32)

# %%
additions = [{'Dimension': 'dg_flavour', 'Content': 'rich malt fruity simple delicate sweetness'},
{'Dimension': 'dg_brand', 'Content': 'street wise street smart smart thinking'}]

# %%
dimensions = dimensions.append(additions)

# %%
dimensions.to_csv('csv/dimensions.csv', index=False)

# %%
dimensions = pd.read_csv('csv/dimensions.csv')

# %% [markdown]
# ## GET WORD VECTORS OF DIMENSIONS

# %%
dimensions['tokens'] = dimensions['Content'].str.lower().str.replace(r'[^a-z ]', '').str.split()

# %%
dimensions['wv'] = dimensions['tokens'].map(lambda x: get_average_vector(x, emb))

# %%
dimensions.head()
# Out:
#       Dimension                                            Content  \
# 0    dg_Relaxed  relax unwind enjoy soothe calm serene leisurel...
# 1  dg_Confident  confident optimistic hopeful reassure certainl...
# 2  dg_Welcoming  welcome greet warmly hospitable invite graciou...
# 3     dg_Social          social civil collective community cordial
# 4    dg_Playful  playful delightful lighthearted lively flirtat...
#
#                                               tokens  \
# 0  [relax, unwind, enjoy, soothe, calm, serene, l...
# 1  [confident, optimistic, hopeful, reassure, cer...
# 2  [welcome, greet, warmly, hospitable, invite, g...
# 3    [social, civil, collective, community, cordial]
# 4  [playful, delightful, lighthearted, lively, fl...
#
#                                                   wv
# 0  [-0.38982093, 1.0310897, -0.3649658, -1.062084...
# 1  [0.35235944, -2.103267, 0.75326306, -2.0183167...
# 2  [0.32264853, -1.3409846, 0.8682901, -1.4583006...
# 3  [0.95336664, -1.0829761, 1.1170304, -0.0309140...
# 4  [-0.72059196, -0.50438666, -0.35774776, -1.436...

# %%
dimensions.shape[0]
# Out:
# 48

# %% [markdown]
# # LOAD CANDIDATE WORDS

# %%
diageo_words_doc_id = '1Vc_NYmC69G0KkdvrUS79jhhu85p5wkhfGnwc9aHTDeM'
diageo_words_doc = download_sheets_doc(diageo_words_doc_id, has_column_labels=True)

# %%
diageo_words_doc.keys()
# Out:
# dict_keys(['malt', 'sweet, sweetness', 'streetwise, streetsmart, thinking, clever, sharp, ease', 'smooth, smoothness', 'richness, rich', 'Smart thinking, Select Indian Barley, delicate sweetness', 'Smart thinking, Extra Malt, rich taste', 'Smart thinking, Select Indian Barley, smooth taste', 'fruity', 'woody wood taste', 'grain', 'malt, rich, malt, fruity, simple, delicate, sweetness', 'malt, streetwise, streetsmart, thinking, clever, sharp, ease', 'grain, rich, malt, fruity, simple, delicate, sweetness', 'malt + brand and flavour profile'])

# %%
ingredients = ['malt', 'grain']
flavors = ['sweet, sweetness',
           'richness, rich',
           'smooth, smoothness',
           'fruity',
           'woody wood taste']
smart_thinking = ['streetwise, streetsmart, thinking, clever, sharp, ease', 'smooth, smoothness']

# %%
def get_words_from_df(df):
    return list(df['Word'].values)

# %%
def filter_words_on_cutoff(words, word2rank_dict, cutoff):
    return [word for word in words if word2rank_dict[word] < cutoff]

# %%
def get_words_for_hook(sheet_dict, hook_keys, word2rank_dict, cutoff):
    container = []
    for key in hook_keys:
        container.extend(get_words_from_df(sheet_dict[key]))
    words = filter_words_on_cutoff(set(container), word2rank_dict, cutoff)
    return words

# %%
words_ingredients = get_words_for_hook(diageo_words_doc, ingredients, word2rank_dict, cutoff)
words_flavors = get_words_for_hook(diageo_words_doc, flavors, word2rank_dict, cutoff)
words_smart_thinking = get_words_for_hook(diageo_words_doc, smart_thinking, word2rank_dict, cutoff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6cb4a75020cd> in <module>()
# ----> 1 words_ingredients = get_words_for_hook(diageo_words_doc, ingredients, word2rank_dict, cutoff)
#       2 words_flavors = get_words_for_hook(diageo_words_doc, flavors, word2rank_dict, cutoff)
#       3 words_smart_thinking = get_words_for_hook(diageo_words_doc, smart_thinking, word2rank_dict, cutoff)
#
# NameError: name 'diageo_words_doc' is not defined

# %%
# number words before filtering
# Out:
# 99
# 193
# 91

# %%
# number words after filtering
# Out:
# 43
# 134
# 69

# %%
def get_df_for_hook(words):
    df = pd.DataFrame(list(words), columns = ['word'])
    df['wv'] = df['word'].map(lambda x: get_average_vector([x], emb))
    return df

# %%
df_ingredients = get_df_for_hook(words_ingredients)
df_flavors = get_df_for_hook(words_flavors)
df_smart_thinking = get_df_for_hook(words_smart_thinking)

# %% [markdown]
# # GET SIMILARITY OF WORDS WITH DIMENSIONS

# %% [markdown]
# ### Construct DF for Diageo selected dimensions

# %%
def cosine_similarity(a,b):
    """
        Compute the cosine similarity of a and b.
    """
    return np.dot(a,b) / ( (np.dot(a,a) **.5) * (np.dot(b,b) ** .5) )

# %%
def get_similarity_with_dimensions(row, dims):
    """
        Get similarity of row's word vector and every dimension.
        row : row of the movie dataframe
        dimensions : dataframe containing Neuroflash dimensions
    """
    for k in range(dims['Dimension'].shape[0]):
        name = 'dim_' + str(dims['Dimension'].iloc[k])
        # define a new column for the cosine similarity of dimension k and the post text
        row[name] = cosine_similarity(row['wv'], dims['wv'].iloc[k])
    return row

# %%
df_ingredients = df_ingredients.apply(lambda x: get_similarity_with_dimensions(x, dimensions), axis=1)
df_flavors = df_flavors.apply(lambda x: get_similarity_with_dimensions(x, dimensions), axis=1)
df_smart_thinking = df_smart_thinking.apply(lambda x: get_similarity_with_dimensions(x, dimensions), axis=1)

# %%
df_ingredients.drop(columns=['wv']).to_csv('csv/sim_ingredients.csv', index=False)
df_flavors.drop(columns=['wv']).to_csv('csv/sim_flavors.csv', index=False)
df_smart_thinking.drop(columns=['wv']).to_csv('csv/sim_smart_thinking.csv', index=False)

# %%
tf = pd.read_csv('csv/top_flavors.csv')
ti = pd.read_csv('csv/top_ingredients.csv')
ts = pd.read_csv('csv/top_smart_thinking.csv')

# %%
tf['rank'] = tf['word'].map(word2rank_dict)
ti['rank'] = ti['word'].map(word2rank_dict)
ts['rank'] = ts['word'].map(word2rank_dict)

# %%
ti.to_csv('csv/top_ingredients_rank.csv', index=False)
tf.to_csv('csv/top_flavors_rank.csv', index=False)
ts.to_csv('csv/top_smart_thinking_rank.csv', index=False)

# %%
def sum_over_dimensions(df, nf_only = True):
    if nf_only:
        consider = df[[x for x in df.columns if 'dim_nf' in x]]
        labels = ['word', 'sum_over_NF_dims']
    else:
        consider = df[[x for x in df.columns if 'dim_' in x]]
        labels = ['word', 'sum_over_dims']
    sum_df = pd.concat([df.iloc[:,0], consider.sum(axis=1)], axis=1)
    sum_df.columns = labels
    return sum_df.sort_values(labels[1], ascending=False)

# %%
sum_over_dimensions(df_flavors).head(20)
# Out:
#                word  sum_over_NF_dims
# 51            truly          5.599674
# 70            charm          5.391906
# 37      wonderfully          5.264797
# 64           subtle          5.234277
# 60          vibrant          5.204802
# 111     comfortable          5.190671
# 121          unique          5.128155
# 118        delicate          4.999129
# 103          earthy          4.872749
# 84        exquisite          4.834724
# 34   sophistication          4.791359
# 46        perfectly          4.754438
# 74         richness          4.682832
# 66         elegance          4.664429
# 45        luxurious          4.605415
# 36         decadent          4.589819
# 62       effortless          4.583854
# 101          gentle          4.551089
# 120       delicious          4.507097
# 122       abundance          4.370026

# %%
sum_over_dimensions(df_smart_thinking).head(20)
# Out:
#             word  sum_over_NF_dims
# 4     attractive          5.384535
# 33        subtle          5.234277
# 52   comfortable          5.190671
# 42    simplicity          5.079498
# 40  sophisticate          5.023508
# 61      delicate          4.999129
# 20     perfectly          4.754438
# 30    effortless          4.583854
# 63        simple          4.563620
# 46        gentle          4.551089
# 55    accentuate          4.381770
# 41  surprisingly          4.348716
# 5        texture          4.217356
# 27  effortlessly          4.139211
# 28         sleek          3.983890
# 14   predictable          3.825299
# 60          soft          3.635670
# 65         silky          3.596671
# 67         witty          3.586665
# 43      flawless          3.510130

# %%
sum_over_dimensions(df_ingredients).to_csv('csv/top_ingredients.csv', index=False)
sum_over_dimensions(df_flavors).to_csv('csv/top_flavors.csv', index=False)
sum_over_dimensions(df_smart_thinking).to_csv('csv/top_smart_thinking.csv', index=False)

# %% [markdown]
# # Plots

# %%
top_ingredients = pd.read_csv('csv/top_ingredients.csv')
top_flavors = pd.read_csv('csv/top_flavors.csv')
top_smart_thinking = pd.read_csv('csv/top_smart_thinking.csv')

# %%
def plot_bargraph(df, hook):
    plt.figure(figsize=(17,9))
    plt.title('Hook: {}'.format(hook), size=20)
    plt.bar(range(min(50, df.shape[0])), df.set_index('word').head(min(50, df.shape[0])).sort_values('sum_over_NF_dims').values)
    plt.xticks(range(min(50, df.shape[0])),  df.head(min(50, df.shape[0])).sort_values('sum_over_NF_dims')['word'], rotation=90, size=15);
    plt.ylabel('Sum of Similarity over Whiskey Dims', size=20)
    plt.savefig('plot/topwords_{}.png'.format(hook), bbox_inches='tight', dpi=300)

# %%
plot_bargraph(top_ingredients, 'ingredients')
plot_bargraph(top_flavors, 'flavors')
plot_bargraph(top_smart_thinking, 'smart_thinking')

# %% [markdown]
# # COMBINATIONS OF STAGE 1 WINNERS
#
# Here we look at combinations from Stage 1. We get similarities with each dimension (NF and DG) then see which combination is best.

# %%
def return_top_k_words(df, k):
    return list(df['word'].head(k).values)

# %%
ingredient_words = return_top_k_words(top_ingredients, 14)
flavors_words = return_top_k_words(top_flavors, 13)
smart_thinking_words = return_top_k_words(top_smart_thinking, 10)

# %%
remove_ingredients = ['fruity', 'coarse', 'harvest', 'distill']
remove_flavors = ['truly', 'charm', 'comfortable']

# %%
ingredient_words = [x for x in ingredient_words if x not in remove_ingredients]
flavors_words = [x for x in flavors_words if x not in remove_flavors]

# %%
combinations = pd.DataFrame(list(product(smart_thinking_words, ingredient_words, flavors_words)), columns = ['smart_thinking', 'ingredient', 'taste'])

# %%
combinations['smart_thinking_wv'] = combinations['smart_thinking'].map(lambda x: get_average_vector([x], emb))
combinations['ingredient_wv'] = combinations['ingredient'].map(lambda x: get_average_vector([x], emb))
combinations['taste_wv'] = combinations['taste'].map(lambda x: get_average_vector([x], emb))
combinations['wv'] = (combinations['smart_thinking_wv'] + combinations['ingredient_wv'] + combinations['taste_wv']) / 3

# %%
combinations = combinations.apply(lambda x: get_similarity_with_dimensions(x, dimensions), axis=1)
combinations = combinations.drop(columns=[x for x in combinations.columns if 'wv' in x])

# %%
combinations['label'] = combinations['smart_thinking'] + ' + ' + combinations['ingredient'] + ' + ' + combinations['taste']
combinations = combinations.set_index('label')

# %%
negative_dg = ['dim_dg_pungent', 'dim_dg_bland', 'dim_dg_bitter']

# %%
combinations['sum_nf'] = combinations[[x for x in combinations.columns if 'nf' in x]].sum(axis=1)
combinations['sum_dg'] = combinations[[x for x in combinations.columns if 'dg' in x  and x not in negative_dg]].sum(axis=1)
combinations['sum_total'] = combinations['sum_nf'] + combinations['sum_dg']

# %%
def plot_bars(dat, dim_type, n):
    negative_dg = ['dim_dg_pungent', 'dim_dg_bland', 'dim_dg_bitter']
    sort_col = {'NF': 'sum_nf', 'DG': 'sum_dg', 'ALL': 'sum_total'}
    plt.figure(figsize=(20, 12))
    dat = dat.sort_values(sort_col[dim_type], ascending=False)
    if dim_type == 'NF':
        dat = dat.loc[:, [x for x in combinations.columns if 'nf_' in x]]
        title = 'Neuro Flash'
    elif dim_type == 'DG': 
        dat = dat.loc[:, [x for x in combinations.columns if ('dg_' in x) and (x not in negative_dg)]]
        title = 'Diageo'
    elif dim_type == 'ALL':
        dat = dat.loc[:, [x for x in combinations.columns if x not in negative_dg and ('dim_' in x)]]
        title = 'Neuro Flash + Diageo'
    dat.columns = [x[7:] for x in dat.columns]
    dat.head(n).plot.bar(ax = plt.gca(), stacked=True, rot = 90, fontsize=20)
    plt.xlabel('')
    plt.title(title, fontsize = 40)
    plt.legend(loc=(1.04,0), fontsize=20, ncol=2)
#     plt.savefig('plot/combs_{}_{}.png'.format(dim_type, n), bbox_inches='tight')

# %%
plot_bars(combinations, 'NF', 15)

# %%
plot_bars(combinations, 'DG', 15)

# %%
plot_bars(combinations, 'ALL', 15)

# %% [markdown]
# # For Diageo Selected Dims

# %%
winner_words = '1TwJ6ychV5At6qhU-nVtBqqEDvVTiTAUuD0YxglwkwIc'
winner_words = download_sheets_doc(winner_words, has_column_labels=True)

# %%
label = ['Dimension', 'tokens']
malt = ['dg_malt', ['malt']]
smoothness = ['dg_smoothness', ['smooth', 'creamy', 'easy', 'fluid', 'gentle', 'mild', 'serene', 'silky', 'velvety', 'sleek']]
smart_thinking =['dg_smart_thinking', ['streetwise', 'streetsmart', 'thinking', 'clever', 'sharp', 'ease']]
richness = ['dg_richness', ['rich', 'richness']]

# %%
chosen_ones = pd.DataFrame.from_records([malt, smoothness, smart_thinking, richness], columns=label)

# %%
chosen_ones['wv'] = chosen_ones['tokens'].map(lambda x: get_average_vector(x, emb))

# %%
chosen_ones
# Out:
#            Dimension                                             tokens  \
# 0            dg_malt                                             [malt]
# 1      dg_smoothness  [smooth, creamy, easy, fluid, gentle, mild, se...
# 2  dg_smart_thinking  [streetwise, streetsmart, thinking, clever, sh...
# 3        dg_richness                                   [rich, richness]
#
#                                                   wv
# 0  [0.6481842, 3.2436092, -1.630463, 0.0014497653...
# 1  [-1.3913215, 1.5429388, -1.9929647, -0.1399003...
# 2  [-0.22701593, 0.6035686, -0.97848374, 1.718363...
# 3  [-0.9195142, 2.466971, -1.8364742, -0.9397965,...

# %%
tf.loc[[x for x in tf.index if x in ['robust','rustic']]]
# Out:
#          rank  dim_dg_malt  dim_dg_smoothness  dim_dg_smart_thinking  \
# word
# robust   9033     0.102087           0.155447               0.111697
# rustic  10234     0.087645           0.146898               0.117365
#
#         dim_dg_richness  sum_over_dims rank_quartile
# word
# robust         0.055580       0.424810             1
# rustic         0.032885       0.384792             1

# %%
# tf = pd.read_csv('csv/top_flavors_rank.csv')
# ti = pd.read_csv('csv/top_ingredients_rank.csv')
# ts = pd.read_csv('csv/top_smart_thinking_rank.csv')

# %%
ti = winner_words['top_ingredients_rank']
ti = ti[ti.iloc[:,-1] != 'x'].drop(columns=['words not chosen (x)'])
tf = winner_words['top_flavors_rank']
tf = tf[tf.iloc[:,-1] != 'x'].drop(columns=['words not chosen (x)'])
ts = winner_words['top_brand_profile_rank']
ts = ts[ts.iloc[:,-1] != 'x'].drop(columns=['words not chosen (x)'])

# %%
tf['wv'] = tf['word'].map(lambda x: get_average_vector(x, emb))
ti['wv'] = ti['word'].map(lambda x: get_average_vector(x, emb))
ts['wv'] = ts['word'].map(lambda x: get_average_vector(x, emb))

# %%
tf = tf.apply(lambda x: get_similarity_with_dimensions(x, chosen_ones), axis=1)
ti = ti.apply(lambda x: get_similarity_with_dimensions(x, chosen_ones), axis=1)
ts = ts.apply(lambda x: get_similarity_with_dimensions(x, chosen_ones), axis=1)

# %%
tf = pd.concat([tf[['word', 'rank', 'dim_dg_malt', 'dim_dg_smoothness', 'dim_dg_smart_thinking', 'dim_dg_richness']], sum_over_dimensions(tf, False).iloc[:,1]], axis=1).sort_values('sum_over_dims', ascending=False).set_index('word')
ti = pd.concat([ti[['word', 'rank', 'dim_dg_malt', 'dim_dg_smoothness', 'dim_dg_smart_thinking', 'dim_dg_richness']], sum_over_dimensions(ti, False).iloc[:,1]], axis=1).sort_values('sum_over_dims', ascending=False).set_index('word')
ts = pd.concat([ts[['word', 'rank', 'dim_dg_malt', 'dim_dg_smoothness', 'dim_dg_smart_thinking', 'dim_dg_richness']], sum_over_dimensions(ts, False).iloc[:,1]], axis=1).sort_values('sum_over_dims', ascending=False).set_index('word')

# %%
tf['rank'] = tf['rank'].astype(int)
ti['rank'] = ti['rank'].astype(int)
ts['rank'] = ts['rank'].astype(int)

# %%
tf['rank_quartile'] = pd.qcut(tf['rank'], 3, [0,1,2])
ti['rank_quartile'] = pd.qcut(ti['rank'], 3, [0,1,2])
ts['rank_quartile'] = pd.qcut(ts['rank'], 3, [0,1,2])

# %%
def get_ordered_top_n(df, n):
    return df.head(n).sort_values('rank_quartile', ascending=True)

# %%
get_ordered_top_n(tf,10)
# Out:
#                 rank  dim_dg_malt  dim_dg_smoothness  dim_dg_smart_thinking  \
# word
# boast           5754     0.060728           0.168323               0.107647
# transition      5036     0.079706           0.157011               0.066179
# taste           2106     0.028753           0.157835               0.104239
# tradition       3757     0.080362           0.155279               0.058018
# robust          9033     0.102087           0.155447               0.111697
# rustic         10234     0.087645           0.146898               0.117365
# citrus         11563     0.087645           0.146898               0.117365
# transparent     7728     0.087221           0.143281               0.041322
# extraordinary   7660     0.105798           0.126650               0.026308
# sorbet         31744     0.070691           0.178627               0.091265
#
#                dim_dg_richness  sum_over_dims rank_quartile
# word
# boast                 0.043363       0.380060             0
# transition            0.039123       0.342018             0
# taste                 0.033919       0.324746             0
# tradition             0.020073       0.313732             0
# robust                0.055580       0.424810             1
# rustic                0.032885       0.384792             1
# citrus                0.032885       0.384792             1
# transparent           0.025690       0.297514             1
# extraordinary         0.033987       0.292743             1
# sorbet                0.037748       0.378332             2

# %%
def solo_bar_plot(df, title, n):
    plt.figure(figsize=(20, 12))
    dat = get_ordered_top_n(df, n)
    ranks = dat['rank_quartile']
    dat = dat[[x for x in df.columns if 'dim_' in x]]
    dat = dat[['dim_dg_smart_thinking', 'dim_dg_malt', 'dim_dg_smoothness', 'dim_dg_richness']]
    dat.columns = [x[7:].replace('_', '-') for x in dat.columns]
    dat.head(n).plot.bar(ax = plt.gca(), stacked=True, rot=22, fontsize=25, align='center')
    plt.xlabel('')
    plt.title(title, fontsize = 40)
    plt.legend(loc=(1.02,0.7), fontsize=30, ncol=1)
    width_dict = {0: 0.75, 1: 0.5, 2: 0.25}
    for container in plt.gca().containers:
        for index,cc in enumerate(container.get_children()):
            old_width = cc.get_width() 
            new_width = width_dict[ranks.iloc[index]]
            diff = new_width - old_width
            plt.setp(cc, width = new_width)
            plt.setp(cc, x = cc.get_x() - 0.5*diff)
    plt.ylabel('Association', fontsize = 35)
    plt.savefig('plot/{}_{}.png'.format(title, n), bbox_inches = 'tight')

# %%
solo_bar_plot(tf, 'Taste Descriptor', 10)
solo_bar_plot(ti, 'Ingredient', 10)
solo_bar_plot(ts, 'Brand Profile', 10)

# %%
ti_words = return_top_k_words(ti.reset_index(), 10)
tf_words = return_top_k_words(tf.reset_index(), 10)
ts_words = return_top_k_words(ts.reset_index(), 10)

# %%
combinations = pd.DataFrame(list(product(ts_words, ti_words, tf_words)), columns = ['smart_thinking', 'ingredient', 'taste'])

# %%
combinations['smart_thinking_wv'] = combinations['smart_thinking'].map(lambda x: get_average_vector([x], emb))
combinations['ingredient_wv'] = combinations['ingredient'].map(lambda x: get_average_vector([x], emb))
combinations['taste_wv'] = combinations['taste'].map(lambda x: get_average_vector([x], emb))
combinations['wv'] = (combinations['smart_thinking_wv'] + combinations['ingredient_wv'] + combinations['taste_wv']) / 3

# %%
combinations = combinations.apply(lambda x: get_similarity_with_dimensions(x, chosen_ones), axis=1)
combinations = combinations.drop(columns=[x for x in combinations.columns if 'wv' in x])

# %%
combinations['label'] = combinations['smart_thinking'] + ' + ' + combinations['ingredient'] + ' + ' + combinations['taste']
combinations = combinations.set_index('label')

# %%
combinations['sum_over_dimensions'] = combinations['dim_dg_malt'] + combinations['dim_dg_smoothness'] + combinations['dim_dg_smart_thinking'] + combinations['dim_dg_richness']

# %%
combinations = combinations.sort_values('sum_over_dimensions', ascending=False)

# %%
combinations
# Out:
#                                           smart_thinking  ingredient  \
# label
# subtle + malt + robust                            subtle        malt
# texture + malt + robust                          texture        malt
# texture + malt + extraordinary                   texture        malt
# soft + malt + extraordinary                         soft        malt
# subtle + malt + extraordinary                     subtle        malt
# subtle + malt + rustic                            subtle        malt
# subtle + malt + boast                             subtle        malt
# texture + malt + rustic                          texture        malt
# soft + malt + robust                                soft        malt
# texture + malt + boast                           texture        malt
# subtle + malt + taste                             subtle        malt
# soft + malt + rustic                                soft        malt
# soft + malt + taste                                 soft        malt
# sophisticate + malt + taste                 sophisticate        malt
# texture + fruity + robust                        texture      fruity
# robust + malt + taste                             robust        malt
# sophisticate + malt + robust                sophisticate        malt
# soft + malt + boast                                 soft        malt
# texture + malt + taste                           texture        malt
# wit + malt + robust                                  wit        malt
# subtle + fruity + robust                          subtle      fruity
# bite + malt + robust                                bite        malt
# texture + malt + transition                      texture        malt
# sophisticate + malt + rustic                sophisticate        malt
# subtle + malt + sorbet                            subtle        malt
# robust + malt + rustic                            robust        malt
# subtle + malt + transition                        subtle        malt
# texture + fruity + extraordinary                 texture      fruity
# texture + fruity + boast                         texture      fruity
# soft + fruity + extraordinary                       soft      fruity
# ...                                                  ...         ...
# straightforward + rum + transparent      straightforward         rum
# transparent + rum + citrus                   transparent         rum
# matte + starch + transparent                       matte      starch
# matte + rum + transparent                          matte         rum
# robust + harvest + transition                     robust     harvest
# matte + harvest + transparent                      matte     harvest
# straightforward + starch + transparent   straightforward      starch
# transparent + oat + transition               transparent         oat
# matte + rum + sorbet                               matte         rum
# transparent + brandy + transition            transparent      brandy
# transparent + distillery + transition        transparent  distillery
# transparent + brandy + sorbet                transparent      brandy
# straightforward + harvest + transition   straightforward     harvest
# transparent + harvest + tradition            transparent     harvest
# straightforward + harvest + transparent  straightforward     harvest
# transparent + starch + sorbet                transparent      starch
# transparent + rum + transition               transparent         rum
# transparent + harvest + citrus               transparent     harvest
# transparent + rum + sorbet                   transparent         rum
# transparent + bourbon + transparent          transparent     bourbon
# transparent + harvest + sorbet               transparent     harvest
# transparent + starch + transition            transparent      starch
# transparent + distill + transparent          transparent     distill
# transparent + distillery + transparent       transparent  distillery
# transparent + oat + transparent              transparent         oat
# transparent + harvest + transition           transparent     harvest
# transparent + brandy + transparent           transparent      brandy
# transparent + rum + transparent              transparent         rum
# transparent + starch + transparent           transparent      starch
# transparent + harvest + transparent          transparent     harvest
#
#                                                  taste  dim_dg_malt  \
# label
# subtle + malt + robust                          robust     0.695015
# texture + malt + robust                         robust     0.689446
# texture + malt + extraordinary           extraordinary     0.693998
# soft + malt + extraordinary              extraordinary     0.708634
# subtle + malt + extraordinary            extraordinary     0.683210
# subtle + malt + rustic                          rustic     0.712726
# subtle + malt + boast                            boast     0.723721
# texture + malt + rustic                         rustic     0.707258
# soft + malt + robust                            robust     0.667983
# texture + malt + boast                           boast     0.716594
# subtle + malt + taste                            taste     0.694586
# soft + malt + rustic                            rustic     0.712916
# soft + malt + taste                              taste     0.699228
# sophisticate + malt + taste                      taste     0.712363
# texture + fruity + robust                       robust     0.297805
# robust + malt + taste                            taste     0.735078
# sophisticate + malt + robust                    robust     0.667075
# soft + malt + boast                              boast     0.714410
# texture + malt + taste                           taste     0.679472
# wit + malt + robust                             robust     0.707899
# subtle + fruity + robust                        robust     0.266714
# bite + malt + robust                            robust     0.628270
# texture + malt + transition                 transition     0.666720
# sophisticate + malt + rustic                    rustic     0.712780
# subtle + malt + sorbet                          sorbet     0.763315
# robust + malt + rustic                          rustic     0.735786
# subtle + malt + transition                  transition     0.664186
# texture + fruity + extraordinary         extraordinary     0.289400
# texture + fruity + boast                         boast     0.355222
# soft + fruity + extraordinary            extraordinary     0.295648
# ...                                                ...          ...
# straightforward + rum + transparent        transparent     0.269124
# transparent + rum + citrus                      citrus     0.338944
# matte + starch + transparent               transparent     0.139396
# matte + rum + transparent                  transparent     0.284728
# robust + harvest + transition               transition     0.092536
# matte + harvest + transparent              transparent     0.132038
# straightforward + starch + transparent     transparent     0.105397
# transparent + oat + transition              transition     0.145219
# matte + rum + sorbet                            sorbet     0.362252
# transparent + brandy + transition           transition     0.242282
# transparent + distillery + transition       transition     0.290345
# transparent + brandy + sorbet                   sorbet     0.336909
# straightforward + harvest + transition      transition     0.078570
# transparent + harvest + tradition            tradition     0.172657
# straightforward + harvest + transparent    transparent     0.094359
# transparent + starch + sorbet                   sorbet     0.196795
# transparent + rum + transition              transition     0.259257
# transparent + harvest + citrus                  citrus     0.168767
# transparent + rum + sorbet                      sorbet     0.345413
# transparent + bourbon + transparent        transparent     0.238997
# transparent + harvest + sorbet                  sorbet     0.180421
# transparent + starch + transition           transition     0.095288
# transparent + distill + transparent        transparent     0.213997
# transparent + distillery + transparent     transparent     0.255356
# transparent + oat + transparent            transparent     0.134827
# transparent + harvest + transition          transition     0.082266
# transparent + brandy + transparent         transparent     0.210228
# transparent + rum + transparent            transparent     0.222364
# transparent + starch + transparent         transparent     0.092486
# transparent + harvest + transparent        transparent     0.084316
#
#                                          dim_dg_smoothness  \
# label
# subtle + malt + robust                            0.557965
# texture + malt + robust                           0.583425
# texture + malt + extraordinary                    0.506595
# soft + malt + extraordinary                       0.548352
# subtle + malt + extraordinary                     0.462580
# subtle + malt + rustic                            0.508264
# subtle + malt + boast                             0.464709
# texture + malt + rustic                           0.535875
# soft + malt + robust                              0.593894
# texture + malt + boast                            0.495416
# subtle + malt + taste                             0.496822
# soft + malt + rustic                              0.567757
# soft + malt + taste                               0.551836
# sophisticate + malt + taste                       0.469837
# texture + fruity + robust                         0.709913
# robust + malt + taste                             0.463635
# sophisticate + malt + robust                      0.488755
# soft + malt + boast                               0.521810
# texture + malt + taste                            0.512858
# wit + malt + robust                               0.424207
# subtle + fruity + robust                          0.680832
# bite + malt + robust                              0.518105
# texture + malt + transition                       0.553912
# sophisticate + malt + rustic                      0.463321
# subtle + malt + sorbet                            0.493512
# robust + malt + rustic                            0.454048
# subtle + malt + transition                        0.520959
# texture + fruity + extraordinary                  0.634287
# texture + fruity + boast                          0.628439
# soft + fruity + extraordinary                     0.681254
# ...                                                    ...
# straightforward + rum + transparent               0.393124
# transparent + rum + citrus                        0.368523
# matte + starch + transparent                      0.483220
# matte + rum + transparent                         0.416758
# robust + harvest + transition                     0.333576
# matte + harvest + transparent                     0.420689
# straightforward + starch + transparent            0.453356
# transparent + oat + transition                    0.432799
# matte + rum + sorbet                              0.364387
# transparent + brandy + transition                 0.378768
# transparent + distillery + transition             0.313527
# transparent + brandy + sorbet                     0.350591
# straightforward + harvest + transition            0.350360
# transparent + harvest + tradition                 0.271893
# straightforward + harvest + transparent           0.375813
# transparent + starch + sorbet                     0.427815
# transparent + rum + transition                    0.372334
# transparent + harvest + citrus                    0.342182
# transparent + rum + sorbet                        0.343238
# transparent + bourbon + transparent               0.344490
# transparent + harvest + sorbet                    0.337354
# transparent + starch + transition                 0.421078
# transparent + distill + transparent               0.341710
# transparent + distillery + transparent            0.294409
# transparent + oat + transparent                   0.390392
# transparent + harvest + transition                0.336558
# transparent + brandy + transparent                0.340633
# transparent + rum + transparent                   0.332513
# transparent + starch + transparent                0.374419
# transparent + harvest + transparent               0.315930
#
#                                          dim_dg_smart_thinking  \
# label
# subtle + malt + robust                                0.375205
# texture + malt + robust                               0.303466
# texture + malt + extraordinary                        0.235795
# soft + malt + extraordinary                           0.289824
# subtle + malt + extraordinary                         0.297197
# subtle + malt + rustic                                0.297077
# subtle + malt + boast                                 0.250503
# texture + malt + rustic                               0.236122
# soft + malt + robust                                  0.339171
# texture + malt + boast                                0.190976
# subtle + malt + taste                                 0.252394
# soft + malt + rustic                                  0.281548
# soft + malt + taste                                   0.242397
# sophisticate + malt + taste                           0.239803
# texture + fruity + robust                             0.390557
# robust + malt + taste                                 0.241759
# sophisticate + malt + robust                          0.337766
# soft + malt + boast                                   0.234440
# texture + malt + taste                                0.198668
# wit + malt + robust                                   0.382681
# subtle + fruity + robust                              0.463474
# bite + malt + robust                                  0.402082
# texture + malt + transition                           0.247996
# sophisticate + malt + rustic                          0.275550
# subtle + malt + sorbet                                0.228817
# robust + malt + rustic                                0.278796
# subtle + malt + transition                            0.312897
# texture + fruity + extraordinary                      0.323165
# texture + fruity + boast                              0.276740
# soft + fruity + extraordinary                         0.381668
# ...                                                        ...
# straightforward + rum + transparent                   0.217723
# transparent + rum + citrus                            0.108766
# matte + starch + transparent                          0.173162
# matte + rum + transparent                             0.113170
# robust + harvest + transition                         0.289813
# matte + harvest + transparent                         0.180276
# straightforward + starch + transparent                0.284482
# transparent + oat + transition                        0.239647
# matte + rum + sorbet                                  0.039449
# transparent + brandy + transition                     0.215667
# transparent + distillery + transition                 0.224451
# transparent + brandy + sorbet                         0.129173
# straightforward + harvest + transition                0.308401
# transparent + harvest + tradition                     0.091286
# straightforward + harvest + transparent               0.287034
# transparent + starch + sorbet                         0.156706
# transparent + rum + transition                        0.168942
# transparent + harvest + citrus                        0.167016
# transparent + rum + sorbet                            0.086296
# transparent + bourbon + transparent                   0.200314
# transparent + harvest + sorbet                        0.156615
# transparent + starch + transition                     0.227217
# transparent + distill + transparent                   0.179890
# transparent + distillery + transparent                0.183659
# transparent + oat + transparent                       0.193661
# transparent + harvest + transition                    0.223345
# transparent + brandy + transparent                    0.170428
# transparent + rum + transparent                       0.133013
# transparent + starch + transparent                    0.180501
# transparent + harvest + transparent                   0.183583
#
#                                          dim_dg_richness  sum_over_dimensions
# label
# subtle + malt + robust                          0.407421             2.035607
# texture + malt + robust                         0.442597             2.018934
# texture + malt + extraordinary                  0.538950             1.975337
# soft + malt + extraordinary                     0.425743             1.972553
# subtle + malt + extraordinary                   0.498010             1.940997
# subtle + malt + rustic                          0.404706             1.922773
# subtle + malt + boast                           0.483148             1.922081
# texture + malt + rustic                         0.438044             1.917298
# soft + malt + robust                            0.314228             1.915276
# texture + malt + boast                          0.511451             1.914438
# subtle + malt + taste                           0.454933             1.898736
# soft + malt + rustic                            0.330894             1.893115
# soft + malt + taste                             0.390353             1.883814
# sophisticate + malt + taste                     0.453609             1.875613
# texture + fruity + robust                       0.476953             1.875228
# robust + malt + taste                           0.432886             1.873358
# sophisticate + malt + robust                    0.375697             1.869293
# soft + malt + boast                             0.397902             1.868562
# texture + malt + taste                          0.473074             1.864071
# wit + malt + robust                             0.333054             1.847840
# subtle + fruity + robust                        0.434932             1.845953
# bite + malt + robust                            0.296283             1.844740
# texture + malt + transition                     0.375523             1.844151
# sophisticate + malt + rustic                    0.389988             1.841640
# subtle + malt + sorbet                          0.347405             1.833049
# robust + malt + rustic                          0.361123             1.829752
# subtle + malt + transition                      0.331638             1.829679
# texture + fruity + extraordinary                0.578057             1.824909
# texture + fruity + boast                        0.560859             1.821259
# soft + fruity + extraordinary                   0.461786             1.820355
# ...                                                  ...                  ...
# straightforward + rum + transparent             0.077179             0.957150
# transparent + rum + citrus                      0.140487             0.956720
# matte + starch + transparent                    0.154620             0.950399
# matte + rum + transparent                       0.134553             0.949209
# robust + harvest + transition                   0.232351             0.948276
# matte + harvest + transparent                   0.208839             0.941841
# straightforward + starch + transparent          0.092736             0.935971
# transparent + oat + transition                  0.113888             0.931553
# matte + rum + sorbet                            0.164416             0.930505
# transparent + brandy + transition               0.093755             0.930472
# transparent + distillery + transition           0.099022             0.927344
# transparent + brandy + sorbet                   0.105683             0.922356
# straightforward + harvest + transition          0.170535             0.907867
# transparent + harvest + tradition               0.369369             0.905205
# straightforward + harvest + transparent         0.146043             0.903248
# transparent + starch + sorbet                   0.116965             0.898281
# transparent + rum + transition                  0.083172             0.883704
# transparent + harvest + citrus                  0.204486             0.882451
# transparent + rum + sorbet                      0.093316             0.868263
# transparent + bourbon + transparent             0.068998             0.852800
# transparent + harvest + sorbet                  0.170075             0.844465
# transparent + starch + transition               0.096579             0.840162
# transparent + distill + transparent             0.097787             0.833384
# transparent + distillery + transparent          0.071294             0.804717
# transparent + oat + transparent                 0.081843             0.800723
# transparent + harvest + transition              0.143667             0.785836
# transparent + brandy + transparent              0.063629             0.784918
# transparent + rum + transparent                 0.055817             0.743706
# transparent + starch + transparent              0.066645             0.714050
# transparent + harvest + transparent             0.108406             0.692235
#
# [1000 rows x 8 columns]
